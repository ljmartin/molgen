# %%
##from https://github.com/eriklindernoren/Keras-GAN/blob/master/infogan/infogan.py


from __future__ import print_function, division

import matplotlib.pyplot as plt

import numpy as onp

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Geometry import Point3D

from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform


from tqdm import tqdm_notebook

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Using an RDF as a scoring function.
#
# An EDM could come from points in many dimensions, so it's possible that there are multiple weird ways to satisfy any given EDM. These ways would all be consistent with other EDMs, and so the network will be happy, but the actual 3D realisation of those EDMs might _do not_ work how we expect.
#
# Alternatively, if we directly learn 3D coordinates, and then compare the euclidean distances to a known distribution, then the network is forced to make the distances consistent with what we expect in 3D space. Put another way, the network can't just put all atoms at the same distance as a carbon-carbon bond distance, because there is not enough volume in 3d dimensions to fit all the atoms surrounding the central atom. The surrounding atoms will thus be forced to move outwards, and hopefully it all settles on a reasonable-looking molecule.
#
# The below fits a loss function using the distributions of known atom distances.
#
# The network part uses JAX numpy, hence the original numpy is re-nicknamed `onp`.

# %%
##load dataset of QM9 isomers. 
mols = list()
smiles = [i.strip('\n') for i in open('larger_dataset.smi', 'r').readlines()]
for smi in smiles:
    mols.append(Chem.MolFromSmiles(smi))

# %%
###draw sample
Draw.MolsToGridImage(onp.random.choice(onp.array(mols), 24), molsPerRow=6)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x800 at 0x7F73070EF1D0>

# %%
###Calculates 3d coordinates of a molecule using RDKit, and then gets a euclidean distance matrix. 
def getEDM(mol):
    #get 3d coords
    m3 = Chem.AddHs(mol)
    embed = AllChem.EmbedMolecule(m3)
    if embed+1:  
        m3 = Chem.RemoveHs(m3)
        conformer = m3.GetConformer(0)
        positions = conformer.GetPositions()
        return positions
    else:
        return None
    
##Less necessary here, but keeping it around as it may be used later. 
##This permutes the indices of the atoms so you don't always have 
##sequental atoms bonded to each other - the 'bonded' distances in the EDM
##should be able to appear anywhere on the board. 
def permute_edm(edm, atom_identities, num_permutes=1000):
    edm= squareform(edm)
    idx = onp.arange(9)
    edm_list = list()
    atom_list = list()
    
    for _ in range(num_permutes):
        onp.random.shuffle(idx)
        edm_copy = edm[idx][:,idx]
        edm_list.append(squareform(edm_copy))
        atom_list.append(atom_identities[idx])
    return edm_list, atom_list

# %%
###Run through molecules and make the EDM dataset. 
edms = list()
atomidx = list()
for count, m in enumerate(onp.random.choice(onp.array(mols), 2000)):
    print(count, end='\r')
    points = getEDM(m)
    if points is None:
        None
    else:
        edm = pdist(points)
        atoms = onp.clip(onp.array([i.GetAtomicNum() for i in m.GetAtoms()])-7, 0, 1)
        el, al = permute_edm(edm, atoms, num_permutes=10)
        for e, a in zip(el, al):
            edms.append(e)
            atomidx.append(a)
# Out:
# 1999

# %% [markdown]
# # Radial Distribution Function
#
# This is the same as a histogram of the pairwise euclidean distances. It plots the density of expected distances. As seen below, there are a number of peaks, which we can probably assign to (left to right) directly bonded atoms (about 1.3 angstrom), atoms separated by one bond (2-3A), atoms separated by two bonds, etc...

# %%
edms = onp.array(edms)
#_ = plt.hist(edms.flatten(), bins=100)
_ = plt.hist(edms.reshape(-1,1), bins=100)
plt.xlabel('Atom distance (angstrom)')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# # Fitting the RDF with a Gaussian Mixture Model
#
# This is a perfect use-case for a gaussian mixture model. Sklearn is fine. Currently fitting with four components because that seems to get the majority of the density, but larger number of components may be better.

# %%
from sklearn.mixture import GaussianMixture

gmm = GaussianMixture(n_components=4, covariance_type='spherical')

gmm.fit(edms.flatten().reshape(-1,1))
# Out:
# GaussianMixture(covariance_type='spherical', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=4, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %% [markdown]
# ### plot to show how the fit is:
# Plot the individual components found by sklearn.
# The true density function is a sum of these components.

# %%
def gaussian(w, x, mu, sig):
    return w*(onp.exp(-(x - mu)**2 / (2 * sig**2)))

x = onp.linspace(0, 10, 200)

##Calculating gaussian heights using the weights from sklearn GMM:
amplitudes = list()
for m, c, w in zip(gmm.means_, gmm.covariances_, gmm.weights_):
    gauss = gaussian(w, x, m, onp.sqrt(c))
    amplitudes.append(1/ onp.trapz(gauss, x) * w )

##Plot individual components as a sanity check.
for m, c, w in zip(gmm.means_, gmm.covariances_, amplitudes):
    plt.plot(x, gaussian(w, x, m, onp.sqrt(c)))

# %%
###Just for fun, plot with scipy.stats norm as well:

from scipy.stats import norm
rvs = list()
for j,k in zip(gmm.means_, gmm.covariances_):
    rv = norm(j, onp.sqrt(k))
    rvs.append(rv)
    
    
hist,edges = onp.histogram(edms.reshape(-1,1), bins=200)
plt.plot(edges[:-1], hist/onp.max(hist), label='Real')
x = onp.linspace(0,10,300)
y = [onp.sum([rv.pdf(v)*w for rv, w in zip(rvs, gmm.weights_)]) for v in x]
plt.plot(x,y/onp.max(y), label='Fitted')

# %% [markdown]
# # Can we turn this into a loss function?
#
# The below just takes the inverse of the gaussians found by the GMM as the loss. This means points in an area of low-density will have larger loss, encouraging all points to be at suitable distances (i.e. high density regions of the GMM).

# %%
#print out values to put into loss function below:
print(gmm.means_, gmm.covariances_**0.5, amplitudes)
# Out:
# [[2.43072157]
#  [4.58717409]
#  [1.44634207]
#  [3.42021894]] [0.1776584  0.89450531 0.0837929  0.4176232 ] [2.2455581762544834, 0.4459921415268217, 4.761051354914721, 0.955268488167468]

# %%
####possibly the hill inbetween 1-bond and 2-bonded atoms is too high to cross? 
def loss(x):
    loss = 1/ (70*(gaussian(0.960, x, 3.42, 0.415)+\
            gaussian(4.749,  x, 1.44, 0.0839)+\
            gaussian(0.456,  x, 4.58, 0.873)+\
            gaussian(2.246,  x, 2.43, 0.177)))
    return loss

plt.figure(figsize=(10,3))
plt.plot(x, onp.log(loss(x)))
plt.ylim(0,2)
plt.plot(x,y/onp.max(y))

# %% [markdown]
# # Can we use this loss function in a neural net?
#
# Using jax.stax here for the net. The idea is to generate coordinates from noise (i.e. latent coordinates like a GAN or a VAE) and to take the loss function as defined above (i.e. the inverse of the gmm density)
#
# The code below borrows from two good examples:
#
#
# There is a great tutorial for doing this: MAML with JAX: https://github.com/ericjang/maml-jax/blob/master/maml.ipynb with more depth explanation at: https://blog.evjang.com/2019/02/maml-jax.html
#
# However some of the code is old. So, also using: https://github.com/google/jax/blob/master/examples/mnist_vae.py which seems more similar to the current task but has no explanation.

# %%
import jax.numpy as np

from jax.config import config
from jax import jit, grad, lax, random, vmap
from jax.experimental import optimizers, stax
from jax.experimental.stax import Dense, Relu, LeakyRelu, Elu
from jax.nn.initializers import he_uniform

# %%
def init_my_network(latent_dims=50):
    test_rng = random.PRNGKey(1)
    _, dec_init_rng = random.split(random.PRNGKey(2))
    decoder_init, decode = stax.serial(
        Dense(256, W_init=he_uniform()), Relu, 
        Dense(256, W_init=he_uniform()), Relu, 
        Dense(27, W_init=he_uniform()),)

    _, init_decoder_params =decoder_init(dec_init_rng, (-1, latent_dims))
    opt_init, opt_update, get_params = optimizers.adam(step_size=1e-4)
    #opt_init, opt_update, get_params = optimizers.adagrad(step_size=1e-5)
    opt_state = opt_init(init_decoder_params)
    return opt_state, opt_update, decode, get_params

@jit
def gaussian(w, x, mu, sig):
    return w*(np.exp(-(x - mu)**2 / (2 * sig**2)))

@jit
def makeCoords(params, noises):
    coords = decode(params, noises)
    return coords

@jit
def pairwise_distances(coords):
    xyz1 = coords.reshape(9,3)
    d0 = np.abs(xyz1[:,0].reshape([-1,1]) - xyz1[:,0])
    d1 = np.abs(xyz1[:,1].reshape([-1,1]) - xyz1[:,1])
    d2 = np.abs(xyz1[:,2].reshape([-1,1]) - xyz1[:,2])
    return (d0+d1+d2)[np.triu_indices(9,1)]

@jit
def loss(p_input, noises_input):
    many_coords = batched_makeCoords(p_input, noises_input)
    many_distances = batched_pairwiseDistances(many_coords)
    distances = many_distances.flatten()
    loss_output = np.sum(1/ (150*(gaussian(0.960, distances, 3.42, 0.415)+\
                          gaussian(4.749, distances, 1.44, 0.083)+\
                          gaussian(0.456, distances, 4.58, 0.873)+\
                          gaussian(2.246, distances, 2.43, 0.177))))
    return loss_output

batched_makeCoords = vmap(makeCoords, in_axes=(None, 0))
batched_pairwiseDistances = vmap(pairwise_distances, in_axes=(0))
gradient_of_loss = grad(loss)

# %%
latent_dims = 50
opt_state, opt_update, decode, get_params = init_my_network(latent_dims=latent_dims)

key = random.PRNGKey(3)
key, noise_key = random.split(key)

loss_list = list()

def step(i, opt_state, key):
    key, noise_key = random.split(key)
    noises = random.normal(noise_key, shape=(2, latent_dims))
    p = get_params(opt_state)   
    g = grad(loss)(p, noises)
    l = loss(p, noises)
    if i%10==0:
        loss_list.append(l)
        print(l)
    return opt_update(i, g, opt_state), key

for i in tqdm_notebook(range(100000)):
    opt_state, key = step(i, opt_state, key)
# Out:
# /home/lewis/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(IntProgress(value=0, max=100000), HTML(value='')))
# 18583224.0
# 1082.443
# 981.22833
# 1410.8502
# 8638.948
# 2025.4938
# 2154.736
# 14.234509
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-210-3e3dabfd5fb2> in <module>
#      19
#      20 for i in tqdm_notebook(range(100000)):
# ---> 21     opt_state, key = step(i, opt_state, key)
#
# <ipython-input-210-3e3dabfd5fb2> in step(i, opt_state, key)
#      16         loss_list.append(l)
#      17         print(l)
# ---> 18     return opt_update(i, g, opt_state), key
#      19
#      20 for i in tqdm_notebook(range(100000)):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/experimental/optimizers.py in tree_update(i, grad_tree, opt_state)
#     157         raise TypeError(msg.format(tree, tree2))
#     158       states = map(tree_unflatten, subtrees, packed_state)
# --> 159       new_states = map(partial(update, i), grad_flat, states)
#     160       new_states_flat, subtrees2 = unzip2(map(tree_flatten, new_states))
#     161       for subtree, subtree2 in zip(subtrees, subtrees2):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/util.py in safe_map(f, *args)
#      37   for arg in args[1:]:
#      38     assert len(arg) == n, 'length mismatch: {}'.format(list(map(len, args)))
# ---> 39   return list(map(f, *args))
#      40
#      41 def unzip2(xys):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/experimental/optimizers.py in update(i, g, state)
#     378     x, m, v = state
#     379     m = (1 - b1) * g + b1 * m  # First  moment estimate.
# --> 380     v = (1 - b2) * (g ** 2) + b2 * v  # Second moment estimate.
#     381     mhat = m / (1 - b1 ** (i + 1))  # Bias correction.
#     382     vhat = v / (1 - b2 ** (i + 1))
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in power(x1, x2)
#     514 def power(x1, x2):
#     515   x1 = asarray(x1)
# --> 516   x2 = asarray(x2)
#     517   x1, x2 = _promote_args_like(onp.power, x1, x2)
#     518   dtype = _dtype(x1)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in asarray(a, dtype, order)
#    1653 def asarray(a, dtype=None, order=None):
#    1654   lax._check_user_dtype_supported(dtype, "asarray")
# -> 1655   return array(a, dtype=dtype, copy=False, order=order)
#    1656
#    1657
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in array(object, dtype, copy, order, ndmin)
#    1625       out = device_put(object)
#    1626   elif isscalar(object):
# -> 1627     out = lax.reshape(object, ())
#    1628     if dtype and _dtype(out) != dtypes.canonicalize_dtype(dtype):
#    1629       out = lax.convert_element_type(out, dtype)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in reshape(operand, new_sizes, dimensions)
#     633         operand, new_sizes=new_sizes,
#     634         dimensions=None if same_dims else tuple(dimensions),
# --> 635         old_sizes=onp.shape(operand))
#     636
#     637 def pad(operand, padding_value, padding_config):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in bind(self, *args, **kwargs)
#     148     top_trace = find_top_trace(args)
#     149     if top_trace is None:
# --> 150       return self.impl(*args, **kwargs)
#     151
#     152     tracers = map(top_trace.full_raise, args)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in _reshape_impl(operand, new_sizes, dimensions, old_sizes)
#    2470   else:
#    2471     return xla.apply_primitive(reshape_p, operand, new_sizes=new_sizes,
# -> 2472                                dimensions=dimensions, old_sizes=old_sizes)
#    2473
#    2474 def _is_axis_merge(s1, s2):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in apply_primitive(prim, *args, **params)
#     140   abstract_args = map(abstractify, args)
#     141   compiled_fun = xla_primitive_callable(prim, *abstract_args, **params)
# --> 142   return compiled_fun(*args)
#     143
#     144 @cache()
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _execute_compiled_primitive(prim, compiled, backend, result_handler, *args)
#     189   device, = compiled.local_devices()
#     190   input_bufs = [device_put(x, device) for x in args if x is not token]
# --> 191   out_buf = compiled.Execute(input_bufs)
#     192   if FLAGS.jax_debug_nans:
#     193     check_nans(prim, out_buf.destructure() if prim.multiple_results else out_buf)
#
# KeyboardInterrupt:

# %%
plt.plot(onp.log(loss_list), linewidth=0.1)

# %%
key = random.PRNGKey(3)
key, noise_key = random.split(key)
noises = random.normal(noise_key, shape=(2, latent_dims))

# %%
p = get_params(opt_state)
m_cor = batched_makeCoords(p, noises)
m_pd = batched_pairwiseDistances(m_cor)
f_pd = m_pd.flatten()
grad(loss)(p, noises)

# %%
grad(loss)(p, noises)
# Out:
# [(DeviceArray([[  -570.3074 ,  -2104.2065 ,    531.0657 , ...,
#                  -4251.875  ,  -5181.4297 ,  -3411.156  ],

# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-8bc16fd92e3f> in <module>
#       2 ##Changing the params really does lead to the exact same
#       3
# ----> 4 grad(loss)([j*2 for j in p], noises)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in grad_f(*args, **kwargs)
#     345   @wraps(fun, docstr=docstr, argnums=argnums)
#     346   def grad_f(*args, **kwargs):
# --> 347     _, g = value_and_grad_f(*args, **kwargs)
#     348     return g
#     349
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     400     f_partial, dyn_args = _argnums_partial(f, argnums, args)
#     401     if not has_aux:
# --> 402       ans, vjp_py = vjp(f_partial, *dyn_args)
#     403     else:
#     404       ans, vjp_py, aux = vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in vjp(fun, *primals, **kwargs)
#    1259   if not has_aux:
#    1260     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1261     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1262     out_tree = out_tree()
#    1263   else:
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     106 def vjp(traceable, primals, has_aux=False):
#     107   if not has_aux:
# --> 108     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     109   else:
#     110     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      95   _, in_tree = tree_flatten(((primals, primals), {}))
#      96   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 97   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      98   pval_primals, pval_tangents = tree_unflatten(out_tree(), out_pvals)
#      99   aval_primals, const_primals = unzip2(pval_primals)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, **kwargs)
#     308   with new_master(JaxprTrace) as master:
#     309     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 310     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     311     assert not env
#     312     del master
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     151
#     152     del gen
# --> 153     ans = self.f(*args, **dict(self.params, **kwargs))
#     154     del args
#     155     while stack:
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     148     _check_args(args_flat)
#     149     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 150     out = xla.xla_call(flat_fun, *args_flat, device=device, backend=backend)
#     151     return tree_unflatten(out_tree(), out)
#     152
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     233     nonzero_tangents, in_tree_def = tree_flatten(tangents)
#     234     f_jvp, out_tree_def = traceable(jvp_subtrace(f, self.master), len(primals), in_tree_def)
# --> 235     result = call_primitive.bind(f_jvp, *(primals + nonzero_tangents), **params)
#     236     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     237     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     109     in_pvs, in_consts = unzip2([t.pval for t in tracers])
#     110     fun, aux = partial_eval(f, self, in_pvs)
# --> 111     out_flat = call_primitive.bind(fun, *in_consts, **params)
#     112     out_pvs, jaxpr, env = aux()
#     113     out_pv_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     590   if top_trace is None:
#     591     with new_sublevel():
# --> 592       outs = primitive.impl(f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, *args, **params)
#     373   device = params['device']
#     374   backend = params.get('backend', None)
# --> 375   compiled_fun = _xla_callable(fun, device, backend, *map(abstractify, args))
#     376   try:
#     377     return compiled_fun(*args)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     207       fun.populate_stores(stores)
#     208     else:
# --> 209       ans = call(fun, *args)
#     210       cache[key] = (ans, fun.stores)
#     211     return ans
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, *abstract_args)
#     389   pvals = [pe.PartialVal((aval, core.unit)) for aval in abstract_args]
#     390   with core.new_master(pe.JaxprTrace, True) as master:
# --> 391     jaxpr, (pvals, consts, env) = pe.trace_to_subjaxpr(fun, master, False).call_wrapped(pvals)
#     392     assert not env  # no subtraces here
#     393     del master, env
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     151
#     152     del gen
# --> 153     ans = self.f(*args, **dict(self.params, **kwargs))
#     154     del args
#     155     while stack:
#
# <ipython-input-133-1fbbe47686de> in loss(p_input, noises_input)
#      18 @jit
#      19 def loss(p_input, noises_input):
# ---> 20     many_coords = batched_makeCoords(p_input, noises_input)
#      21     many_distances = batched_pairwiseDistances(many_coords)
#      22     distances = many_distances.flatten()
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in batched_fun(*args)
#     685     _check_axis_sizes(in_tree, args_flat, in_axes_flat)
#     686     out_flat = batching.batch(flat_fun, args_flat, in_axes_flat,
# --> 687                               lambda: _flatten_axes(out_tree(), out_axes))
#     688     return tree_unflatten(out_tree(), out_flat)
#     689
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/batching.py in batch(fun, in_vals, in_dims, out_dim_dests)
#      41 def batch(fun, in_vals, in_dims, out_dim_dests):
#      42   size, = {x.shape[d] for x, d in zip(in_vals, in_dims) if d is not not_mapped}
# ---> 43   out_vals, out_dims = batch_fun(fun, in_vals, in_dims)
#      44   return map(partial(matchaxis, size), out_dims, out_dim_dests(), out_vals)
#      45
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/batching.py in batch_fun(fun, in_vals, in_dims)
#      47   with new_master(BatchTrace) as master:
#      48     fun, out_dims = batch_subtrace(fun, master, in_dims)
# ---> 49     out_vals = fun.call_wrapped(*in_vals)
#      50     del master
#      51   return out_vals, out_dims()
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     151
#     152     del gen
# --> 153     ans = self.f(*args, **dict(self.params, **kwargs))
#     154     del args
#     155     while stack:
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     148     _check_args(args_flat)
#     149     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 150     out = xla.xla_call(flat_fun, *args_flat, device=device, backend=backend)
#     151     return tree_unflatten(out_tree(), out)
#     152
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/batching.py in process_call(self, call_primitive, f, tracers, params)
#     130     else:
#     131       f, dims_out = batch_subtrace(f, self.master, dims)
# --> 132       vals_out = call_primitive.bind(f, *vals, **params)
#     133       return [BatchTracer(self, v, d) for v, d in zip(vals_out, dims_out())]
#     134
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     233     nonzero_tangents, in_tree_def = tree_flatten(tangents)
#     234     f_jvp, out_tree_def = traceable(jvp_subtrace(f, self.master), len(primals), in_tree_def)
# --> 235     result = call_primitive.bind(f_jvp, *(primals + nonzero_tangents), **params)
#     236     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     237     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     109     in_pvs, in_consts = unzip2([t.pval for t in tracers])
#     110     fun, aux = partial_eval(f, self, in_pvs)
# --> 111     out_flat = call_primitive.bind(fun, *in_consts, **params)
#     112     out_pvs, jaxpr, env = aux()
#     113     out_pv_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     109     in_pvs, in_consts = unzip2([t.pval for t in tracers])
#     110     fun, aux = partial_eval(f, self, in_pvs)
# --> 111     out_flat = call_primitive.bind(fun, *in_consts, **params)
#     112     out_pvs, jaxpr, env = aux()
#     113     out_pv_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     590   if top_trace is None:
#     591     with new_sublevel():
# --> 592       outs = primitive.impl(f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, *args, **params)
#     373   device = params['device']
#     374   backend = params.get('backend', None)
# --> 375   compiled_fun = _xla_callable(fun, device, backend, *map(abstractify, args))
#     376   try:
#     377     return compiled_fun(*args)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     207       fun.populate_stores(stores)
#     208     else:
# --> 209       ans = call(fun, *args)
#     210       cache[key] = (ans, fun.stores)
#     211     return ans
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, *abstract_args)
#     389   pvals = [pe.PartialVal((aval, core.unit)) for aval in abstract_args]
#     390   with core.new_master(pe.JaxprTrace, True) as master:
# --> 391     jaxpr, (pvals, consts, env) = pe.trace_to_subjaxpr(fun, master, False).call_wrapped(pvals)
#     392     assert not env  # no subtraces here
#     393     del master, env
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     151
#     152     del gen
# --> 153     ans = self.f(*args, **dict(self.params, **kwargs))
#     154     del args
#     155     while stack:
#
# <ipython-input-133-1fbbe47686de> in makeCoords(params, noises)
#       5 @jit
#       6 def makeCoords(params, noises):
# ----> 7     coords = decode(params, noises)
#       8     return coords
#       9
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/experimental/stax.py in apply_fun(params, inputs, **kwargs)
#     287     rngs = random.split(rng, nlayers) if rng is not None else (None,) * nlayers
#     288     for fun, param, rng in zip(apply_funs, params, rngs):
# --> 289       inputs = fun(param, inputs, rng=rng, **kwargs)
#     290     return inputs
#     291   return init_fun, apply_fun
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/experimental/stax.py in apply_fun(params, inputs, **kwargs)
#      60     return output_shape, (W, b)
#      61   def apply_fun(params, inputs, **kwargs):
# ---> 62     W, b = params
#      63     return np.dot(inputs, W) + b
#      64   return init_fun, apply_fun
#
# ValueError: too many values to unpack (expected 2)

# %%
g_loss = grad(loss)

def step(i, opt_state, key):
    key, noise_key = random.split(key)
    noise = random.normal(noise_key, shape=(2, latent_dims))
    p = get_params(opt_state)
    
    g = g_loss(p, noise)
    #g = loss_grad(p, noise)
    return opt_update(i, g, opt_state), key

# %%
##Training part:
losslist = list()
key = random.PRNGKey(1)
for i in tqdm_notebook(range(50000)):
    opt_state, key = step(i, opt_state, key)
# Out:
# /home/lewis/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/numpy/core/fromnumeric.py in size(a, axis)
#    3064         try:
# -> 3065             return a.size
#    3066         except AttributeError:
#
# AttributeError: 'list' object has no attribute 'size'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-282-4b6cdc88a5e6> in <module>
#       3 key = random.PRNGKey(1)
#       4 for i in tqdm_notebook(range(50000)):
# ----> 5     opt_state, key = step(i, opt_state, key)
#
# <ipython-input-281-88816c1a78ef> in step(i, opt_state, key)
#       6     p = get_params(opt_state)
#       7
# ----> 8     g = g_loss(p, noise)
#       9     #g = loss_grad(p, noise)
#      10     #l =  loss(p, noise)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in grad_f(*args, **kwargs)
#     345   @wraps(fun, docstr=docstr, argnums=argnums)
#     346   def grad_f(*args, **kwargs):
# --> 347     _, g = value_and_grad_f(*args, **kwargs)
#     348     return g
#     349
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     400     f_partial, dyn_args = _argnums_partial(f, argnums, args)
#     401     if not has_aux:
# --> 402       ans, vjp_py = vjp(f_partial, *dyn_args)
#     403     else:
#     404       ans, vjp_py, aux = vjp(f_partial, *dyn_args, has_aux=True)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in vjp(fun, *primals, **kwargs)
#    1259   if not has_aux:
#    1260     flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 1261     out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    1262     out_tree = out_tree()
#    1263   else:
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     106 def vjp(traceable, primals, has_aux=False):
#     107   if not has_aux:
# --> 108     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     109   else:
#     110     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      95   _, in_tree = tree_flatten(((primals, primals), {}))
#      96   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# ---> 97   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#      98   pval_primals, pval_tangents = tree_unflatten(out_tree(), out_pvals)
#      99   aval_primals, const_primals = unzip2(pval_primals)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, **kwargs)
#     308   with new_master(JaxprTrace) as master:
#     309     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 310     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     311     assert not env
#     312     del master
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     151
#     152     del gen
# --> 153     ans = self.f(*args, **dict(self.params, **kwargs))
#     154     del args
#     155     while stack:
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     148     _check_args(args_flat)
#     149     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 150     out = xla.xla_call(flat_fun, *args_flat, device=device, backend=backend)
#     151     return tree_unflatten(out_tree(), out)
#     152
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     233     nonzero_tangents, in_tree_def = tree_flatten(tangents)
#     234     f_jvp, out_tree_def = traceable(jvp_subtrace(f, self.master), len(primals), in_tree_def)
# --> 235     result = call_primitive.bind(f_jvp, *(primals + nonzero_tangents), **params)
#     236     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     237     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
# --> 595     outs = map(full_lower, top_trace.process_call(primitive, f, tracers, params))
#     596   return apply_todos(env_trace_todo(), outs)
#     597
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#     109     in_pvs, in_consts = unzip2([t.pval for t in tracers])
#     110     fun, aux = partial_eval(f, self, in_pvs)
# --> 111     out_flat = call_primitive.bind(fun, *in_consts, **params)
#     112     out_pvs, jaxpr, env = aux()
#     113     out_pv_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in call_bind(primitive, f, *args, **params)
#     590   if top_trace is None:
#     591     with new_sublevel():
# --> 592       outs = primitive.impl(f, *args, **params)
#     593   else:
#     594     tracers = map(top_trace.full_raise, args)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, *args, **params)
#     373   device = params['device']
#     374   backend = params.get('backend', None)
# --> 375   compiled_fun = _xla_callable(fun, device, backend, *map(abstractify, args))
#     376   try:
#     377     return compiled_fun(*args)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     207       fun.populate_stores(stores)
#     208     else:
# --> 209       ans = call(fun, *args)
#     210       cache[key] = (ans, fun.stores)
#     211     return ans
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, *abstract_args)
#     389   pvals = [pe.PartialVal((aval, core.unit)) for aval in abstract_args]
#     390   with core.new_master(pe.JaxprTrace, True) as master:
# --> 391     jaxpr, (pvals, consts, env) = pe.trace_to_subjaxpr(fun, master, False).call_wrapped(pvals)
#     392     assert not env  # no subtraces here
#     393     del master, env
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     151
#     152     del gen
# --> 153     ans = self.f(*args, **dict(self.params, **kwargs))
#     154     del args
#     155     while stack:
#
# <ipython-input-273-a545560d5bdd> in loss(p, noises)
#      26 @jit
#      27 def loss(p, noises):
# ---> 28     sums = np.mean(quick_batch_noise(p, noises))
#      29     return sums
#      30
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/numpy/lax_numpy.py in mean(a, axis, dtype, out, keepdims)
#    1229
#    1230   if axis is None:
# -> 1231     normalizer = size(a)
#    1232   else:
#    1233     normalizer = onp.prod(onp.take(shape(a), axis))
#
# <__array_function__ internals> in size(*args, **kwargs)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/numpy/core/fromnumeric.py in size(a, axis)
#    3065             return a.size
#    3066         except AttributeError:
# -> 3067             return asarray(a).size
#    3068     else:
#    3069         try:
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in __iter__(self)
#     289
#     290   def __iter__(self):
# --> 291     return iter(self.aval._iter(self))
#     292
#     293   def __len__(self):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in _iter(tracer)
#    1449     n = tracer.shape[0]
#    1450     # return (index_in_dim(tracer, i, keepdims=False) for i in xrange(n))
# -> 1451     return iter([index_in_dim(tracer, i, keepdims=False) for i in xrange(n)])
#    1452 ShapedArray._iter = staticmethod(_iter)
#    1453
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in <listcomp>(.0)
#    1449     n = tracer.shape[0]
#    1450     # return (index_in_dim(tracer, i, keepdims=False) for i in xrange(n))
# -> 1451     return iter([index_in_dim(tracer, i, keepdims=False) for i in xrange(n)])
#    1452 ShapedArray._iter = staticmethod(_iter)
#    1453
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in index_in_dim(operand, index, axis, keepdims)
#    1316     msg = 'index {} is out of bounds for axis {} with size {}'
#    1317     raise IndexError(msg.format(index, axis, axis_size))
# -> 1318   result = slice_in_dim(operand, wrapped_index, wrapped_index + 1, 1, axis)
#    1319   if keepdims:
#    1320     return result
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in slice_in_dim(operand, start_index, limit_index, stride, axis)
#    1305   strides[axis] = int(stride)
#    1306
# -> 1307   return slice(operand, start_indices, limit_indices, strides)
#    1308
#    1309
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in slice(operand, start_indices, limit_indices, strides)
#     669                         limit_indices=tuple(limit_indices),
#     670                         strides=None if strides is None else tuple(strides),
# --> 671                         operand_shape=operand.shape)
#     672
#     673 def dynamic_slice(operand, start_indices, slice_sizes):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in bind(self, *args, **kwargs)
#     151
#     152     tracers = map(top_trace.full_raise, args)
# --> 153     out_tracer = top_trace.process_primitive(self, tracers, kwargs)
#     154     if self.multiple_results:
#     155       return map(full_lower, out_tracer)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in process_primitive(self, primitive, tracers, params)
#     221           "Forward-mode differentiation rule for '{}' not implemented"
#     222           .format(primitive))
# --> 223     primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     224     if primitive.multiple_results:
#     225       return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/ad.py in linear_jvp(primitive, primals, tangents, **params)
#     307   else:
#     308     tangents = map(instantiate_zeros, primals, tangents)
# --> 309     return val_out, primitive.bind(*tangents, **params)
#     310
#     311 def linear_transpose(transpose_rule, cotangent, *args, **kwargs):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/core.py in bind(self, *args, **kwargs)
#     151
#     152     tracers = map(top_trace.full_raise, args)
# --> 153     out_tracer = top_trace.process_primitive(self, tracers, kwargs)
#     154     if self.multiple_results:
#     155       return map(full_lower, out_tracer)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in process_primitive(self, primitive, tracers, params)
#      92       tracers = map(self.instantiate_const, tracers)
#      93       avals = [t.aval for t in tracers]
# ---> 94       out_aval = primitive.abstract_eval(*avals, **params)
#      95       if primitive.multiple_results:
#      96         out_tracers = [JaxprTracer(self, PartialVal((aval, unit)), None)
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in standard_abstract_eval(shape_rule, dtype_rule, *args, **kwargs)
#    1493     return ShapedArray(shape_rule(*args, **kwargs), dtype_rule(*args, **kwargs))
#    1494   elif least_specialized is ShapedArray:
# -> 1495     return ShapedArray(shape_rule(*args, **kwargs), dtype_rule(*args, **kwargs))
#    1496   elif least_specialized is UnshapedArray:
#    1497     return UnshapedArray(dtype_rule(*args, **kwargs))
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in _slice_shape_rule(operand, start_indices, limit_indices, strides, operand_shape)
#    2650 def _slice_shape_rule(operand, start_indices, limit_indices, strides,
#    2651                       operand_shape):
# -> 2652   _check_shapelike("slice", "start_indices", start_indices)
#    2653   _check_shapelike("slice", "limit_indices", limit_indices)
#    2654   if operand.ndim != len(start_indices):
#
# ~/miniconda3/envs/tf_gpu/lib/python3.7/site-packages/jax/lax/lax.py in _check_shapelike(fun_name, arg_name, obj)
#    4370   if not len(obj):  # pylint: disable=g-explicit-length-test
#    4371     return
# -> 4372   obj_arr = onp.array(obj)
#    4373   if obj_arr.ndim != 1:
#    4374     msg = "{} {} must be rank 1, got {}."
#
# KeyboardInterrupt:

# %% [markdown]
# # How does it look?
#
# Predict some coordinates and plot to see if they are at least consistent with the expected radial distribution function.

# %%
key, noise_key = random.split(key)
noise = random.normal(noise_key, shape=(latent_dims,))
p = get_params(opt_state)
coords = decode(p, noise).reshape(9,3)
distance_matrix = pairwise_distances(coords, coords)
distances = distance_matrix[np.triu_indices(9,1)]

# %%
plt.hist(distances, bins=36)
plt.scatter(distances, np.zeros(len(distances))-0.5, alpha=0.5)

# %%
edm = squareform(distances)
plt.imshow(squareform(distances))
plt.colorbar()

# %%
def to_M_matrix(D):
    D1j = np.tile(D[0, :], len(D)).reshape(D.shape)
    Di1 = D1j.T
    return .5 * (-D + D1j + Di1)

def setPositions(mol_in, coords):
    conformer = mol_in.GetConformer(0)
    for i in range(mol_in.GetNumAtoms()):
        x,y,z = coords[i]
        conformer.SetAtomPosition(i,Point3D(x,y,z))
    return mol_in

D = edm**2
M = to_M_matrix(D)
S, U = np.linalg.eigh(M)

coord = np.matmul(U, np.diag(np.sqrt(np.abs(S))))
X = coord[:, -3:]

# %%
def get_proto_mol(atomicNumList):
    mol = Chem.MolFromSmarts("[#"+str(atomicNumList[0])+"]")
    rwMol = Chem.RWMol(mol)
    for i in range(1,len(atomicNumList)):
        a = Chem.Atom(atomicNumList[i])
        rwMol.AddAtom(a)

    mol = rwMol.GetMol()

    return mol


def xyz2AC(atomicNumList,xyz):
    import numpy as np
    mol = get_proto_mol(atomicNumList)

    conf = Chem.Conformer(mol.GetNumAtoms())
    for i in range(mol.GetNumAtoms()):
        conf.SetAtomPosition(i,(float(xyz[i][0]),float(xyz[i][1]),float(xyz[i][2])))
    mol.AddConformer(conf)

    dMat = Chem.Get3DDistanceMatrix(mol)
    pt = Chem.GetPeriodicTable()

    num_atoms = len(atomicNumList)
    AC = np.zeros((num_atoms,num_atoms)).astype(int)

    for i in range(num_atoms):
        a_i = mol.GetAtomWithIdx(i)
        Rcov_i = pt.GetRcovalent(a_i.GetAtomicNum())*1.10
        for j in range(i+1,num_atoms):
            a_j = mol.GetAtomWithIdx(j)
            Rcov_j = pt.GetRcovalent(a_j.GetAtomicNum())*1.10
            if dMat[i,j] <= Rcov_i + Rcov_j:
                AC[i,j] = 1
                AC[j,i] = 1

    return AC,mol

# %% [markdown]
# --------------
# _Remember_ - you can use either the EDM-coords or the real coordinates to generate a molecule
#
#
#
# Somehow these are different. They should be the same!!

# %%
atomicNumList = [6]*9



#use either 'X' or 'coords'
am, mol =xyz2AC(atomicNumList,coords)

# %%
eMol = Chem.EditableMol(mol)

bonds = np.triu(am)
for j, k in zip(onp.where(bonds)[0], onp.where(bonds)[1]):
    print(j,k)
    try:
        eMol.AddBond(int(j),int(k))
    except:
        None
# Out:
# 0 3
# 1 3
# 1 5
# 1 6
# 2 3
# 2 4
# 2 6
# 2 7
# 3 4
# 3 6
# 3 8

# %%
mol = eMol.GetMol()

Chem.rdmolfiles.MolToPDBFile(mol, 'tempmol.pdb', flavor=0)
mol

# %%
mol.Compute2DCoords()
mol
